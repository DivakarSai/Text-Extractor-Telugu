# %%
import cv2
from video import Video
import pprint

# %%
# Open the video file
path = "videos/curr_video.mp4"
video = Video(path)

# %%
from textExtraction import text_from_video

# %%
x,y,w,h = 300,800,1600,160
breaking_news_region = (x,y,w,h)

# %%
result = text_from_video(video, breaking_news_region)

print(result)
# Out:
# current frame: ['శ్రీవారి', 'హుండీ', 'ఆదాయం', 'రూ.3.72', 'కోట్లు']
# final string: ['శ్రీవారి', 'హుండీ', 'ఆదాయం', 'రూ.3.72', 'కోట్లు']
# current frame: ['శ్రీవారి', 'హుండీ', 'ఆదాయం', 'రూ.3.72', 'కోట్లు']
# final string: ['శ్రీవారి', 'హుండీ', 'ఆదాయం', 'రూ.3.72', 'కోట్లు']
# current frame: ['క:']
# final string: ['శ్రీవారి', 'హుండీ', 'ఆదాయం', 'రూ.3.72', 'క:']
# current frame: []
# final string: ['శ్రీవారి', 'హుండీ', 'ఆదాయం', 'రూ.3.72', 'క:']
# current frame: ['ఎమైన']
# final string: ['శ్రీవారి', 'హుండీ', 'ఆదాయం', 'రూ.3.72', 'ఎమైన']
# current frame: []
# final string: ['శ్రీవారి', 'హుండీ', 'ఆదాయం', 'రూ.3.72', 'ఎమైన']
# current frame: ['హైదరాబా', 'ద్\u200c', 'న్\u200c్\u200c']
# final string: ['శ్రీవారి', 'హుండీ', 'ఆదాయం', 'రూ.3.72', 'హైదరాబా', 'ద్\u200c', 'న్\u200c్\u200c']
# current frame: ['హైదరాబాద్\u200c:', 'బాచుపల్లిలో', 'దారు', 'ఐ', '|']
# final string: ['శ్రీవారి', 'హుండీ', 'ఆదాయం', 'రూ.3.72', 'హైదరాబా', 'ద్\u200c', 'హైదరాబాద్\u200c:', 'బాచుపల్లిలో', 'దారు', 'ఐ', '|']
# ...

# %%
print(result)
# Out:
# శ్రీవారి హుండీ ఆదాయం రూ.3.72 హైదరాబా ద్‌ హైదరాబాద్‌: బాచుపల్లిలో దారు ఐ హైదరాబాద్‌: బాచుపల్లిలో దారుణం హైదరాబాద్‌: బాచుపల్లిలో ప్రగతిన = 11ర్తేటీ ప్రగతినగర్‌ చెరువు దగ్గర తేజస్‌ అనే యువకుడి హత్య ప్రగతినగర్‌ చెరువు దగ్గర తేజస్‌ అనే యువకుడి ప్రగతినగర్‌ చెరువు దగ్గర తేజస్‌ను వెంటాడి చంపిన ప్రత్యర్థులు లేజస్‌ను వెంటాడి చంపిన ప్రత్యర్థులు న్స్‌ తేజస్‌ను వెంటాడి చంపిన ప్రత్యర్థులు క్‌ ఒఅ ననన కనాన వ చం. కనన ముామోనా కనీ ఓ హత్యకేసులో నిందితుడిగా ఉన్న లేజస్‌ 4 ఓ హత్యకేసులో నిందితుడిగా ఉన్న ఓ హత్యకేసులో నిందితుడిగా ఉన్నతేజస్‌ ఓ హత్యకేసులో నిందితుడిగా ఉన్న ఓ హత్యకేసులో నిందితుడిగా యాతి బన న తన. కలత నటే తతత కలన త్య తన తాలననా | తే తేజస్‌ హత్యచేసి ఇన్‌స్టాలో రీల్‌ చేసిన నిందితులు 1 1కే క్ష తేజస్‌ హత్యచేసి ఇన్‌స్టాలో రీల్‌ చేసిన నిం. తే న ననీ తక నానన లేజస్‌ను హత్యచేశామంటూ వీడియో పెట్టిన నిందితులు తేజస్‌ను హత్యచేశామంటూ వీడియో పెట్టిన నిందితులు ౫ శశిక (మిం 11,72 బ్‌ య 4... క మణి యుత125:(. గ్‌ 117౬౧ 0౯6౧౯౬ ఆ (గ8ికీలక్‌ి 4156| ౧౯౦ 884 | 8.60గ) 888555 66 11 కిట | కాయలంత |! నతని! కయలకులికినకినం |! సమునసుట
# ...
